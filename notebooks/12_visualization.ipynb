# %% [markdown]
# # 12: Executive Presentation Visualizations & Artifacts
# ## Final Dashboard Charts & Strategic Action Blueprint

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Overall Funnel Conversion Rate', 'Top Department Drop-off Rates'),
    specs=[[{'type': 'domain'}, {'type': 'xy'}]]
)

fig.add_trace(go.Pie(
    labels=['Joined (22.2%)', 'Accepted Never Joined (3.3%)', 'Dropped (74.5%)'],
    values=[1470, 221, 4942],
    marker_colors=['#22C55E', '#F43F5E', '#64748B'],
    hole=.6
), row=1, col=1)

fig.add_trace(go.Bar(
    x=['IT', 'Sales', 'Product', 'Finance'],
    y=[48.7, 46.0, 31.2, 23.9],
    marker_color=['#EF4444', '#F97316', '#F59E0B', '#22C55E']
), row=1, col=2)

fig.update_layout(title_text='Recruitflow Talent Command Executive Summary', template='plotly_dark')
fig.show()
